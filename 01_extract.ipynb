# %%
# Notebook 01 - Extract
# Load the 9 CSV files from the Bronze layer

BRONZE_PATH = "/Volumes/olist_project/bronze/raw_data"

df_customers = spark.read.csv(f"{BRONZE_PATH}/olist_customers_dataset.csv", header=True, inferSchema=True)
df_orders = spark.read.csv(f"{BRONZE_PATH}/olist_orders_dataset.csv", header=True, inferSchema=True)
df_order_items = spark.read.csv(f"{BRONZE_PATH}/olist_order_items_dataset.csv", header=True, inferSchema=True)
df_payments = spark.read.csv(f"{BRONZE_PATH}/olist_order_payments_dataset.csv", header=True, inferSchema=True)
df_reviews = spark.read.csv(f"{BRONZE_PATH}/olist_order_reviews_dataset.csv", header=True, inferSchema=True)
df_products = spark.read.csv(f"{BRONZE_PATH}/olist_products_dataset.csv", header=True, inferSchema=True)
df_sellers = spark.read.csv(f"{BRONZE_PATH}/olist_sellers_dataset.csv", header=True, inferSchema=True)
df_geolocation = spark.read.csv(f"{BRONZE_PATH}/olist_geolocation_dataset.csv", header=True, inferSchema=True)
df_category = spark.read.csv(f"{BRONZE_PATH}/product_category_name_translation.csv", header=True, inferSchema=True)

print("Files loaded successfully!")
# Out:
# Files loaded successfully!

# %%
# Check the number of rows and columns for each dataset

print("customers: ", df_customers.count(), "rows |", len(df_customers.columns), "columns")
print("orders: ", df_orders.count(), "rows |", len(df_orders.columns), "columns")
print("order_items: ", df_order_items.count(), "rows |", len(df_order_items.columns), "columns")
print("payments: ", df_payments.count(), "rows |", len(df_payments.columns), "columns")
print("reviews: ", df_reviews.count(), "rows |", len(df_reviews.columns), "columns")
print("products: ", df_products.count(), "rows |", len(df_products.columns), "columns")
print("sellers: ", df_sellers.count(), "rows |", len(df_sellers.columns), "columns")
print("geolocation: ", df_geolocation.count(), "rows |", len(df_geolocation.columns), "columns")
print("category: ", df_category.count(), "rows |", len(df_category.columns), "columns")
# Out:
# customers:  99441 rows | 5 columns
# orders:  99441 rows | 8 columns
# order_items:  112650 rows | 7 columns
# payments:  103886 rows | 5 columns
# reviews:  104162 rows | 7 columns
# products:  32951 rows | 9 columns
# sellers:  3095 rows | 4 columns
# geolocation:  1000163 rows | 5 columns
# category:  71 rows | 2 columns
